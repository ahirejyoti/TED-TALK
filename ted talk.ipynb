# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #import libbrary

# %%
df = pd.read_csv('tedtalk.csv')

# %%
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# ...

# %%
df.shape
# Out:
# (5440, 6)

# %% [markdown]
# #read the Data properly they have 6 columns and 5440 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5439 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %%
df.isnull().sum()
# Out:
# title     0
# author    1
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %% [markdown]
# #we check the null values but 1 null values is avilable in author.

# %%
df.corr()
# Out:
#           views     likes
# views  1.000000  0.999661
# likes  0.999661  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # checking the corelation between features. likes and views are heighly corelated with each other.

# %% [markdown]
# #we checking the unique value of features

# %%
 df['title'].unique()
# Out:
# array(['Climate action needs new frontline leadership',
#        'The dark history of the overthrow of Hawaii',
#        'How play can spark new ideas for your business', ...,
#        'Greening the ghetto', 'Simplicity sells',
#        'Averting the climate crisis'], dtype=object)

# %%
 df['author'].unique()
# Out:
# array(['Ozawa Bineshi Albert', 'Sydney Iaukea', 'Martin Reeves', ...,
#        'Jeff Han', 'Jehane Noujaim', 'Rick Warren'], dtype=object)

# %%
 df['date'].unique()
# Out:
# array(['December 2021', 'February 2022', 'September 2021', 'October 2021',
#        'August 2021', 'March 2019', 'January 2022', 'November 2021',
#        'July 2021', 'June 2021', 'March 2021', 'April 2021', 'May 2021',
#        'August 2019', 'March 2016', 'May 2017', 'April 2016',
#        'September 2020', 'September 2015', 'November 2020',
#        'February 2020', 'February 2021', 'August 2020', 'May 2016',
#        'November 2014', 'December 2020', 'April 2019', 'October 2020',
#        'June 2020', 'March 2020', 'May 2020', 'July 2020', 'January 2021',
#        'October 2017', 'July 2017', 'April 2018', 'April 2017',
#        'September 2017', 'December 2019', 'November 2019', 'May 2019',
#        'January 2020', 'September 2019', 'February 2015', 'July 2015',
#        'February 2017', 'January 2019', 'January 1970', 'November 2016',
#        'September 2016', 'December 2018', 'September 2014',
#        'November 2015', 'April 2020', 'October 2012', 'October 2019',
# ...

# %%
 df['views'].unique()
# Out:
# array([  404000,   214000,   412000,   427000,     2400,   422000,
#          455000,    66000,   584000,    87000,   213000,   622000,
#          526000,    23000,   628000,   459000,   522000,    96000,
#            4500,     1600,   667000,   456000,   632000,    97000,
#          609000,   363000,   649000,   134000,   613000,   817000,
#          411000,   700000,   678000,    30000,   743000,   669000,
#          766000,   789000,   800000,   601000,   732000,   751000,
#          998000,   786000,  1000000,    20000,  2300000,    10000,
#          880000,  1500000,    19000,   825000,    90000,   888000,
#          839000,   951000,   761000,   992000,   861000,    11000,
#         1100000,   864000,   724000,   295000,  1300000,   969000,
#          986000,   837000,   527000,   311000,  1200000,     3800,
#          981000,   200000,     2500,     4900,   635000,     4000,
#          315000,   714000,  1400000,   475000,   277000,   357000,
# ...

# %%
 df['likes'].unique()
# Out:
# array([  12000,    6400,      72,   13000,    1900,   17000,    2600,
#          18000,   15000,     690,    2900,     135,      49,   20000,
#          10000,   19000,    4000,   24000,   21000,     913,   22000,
#          23000,   29000,   32000,     606,   70000,     312,   26000,
#          47000,     580,    2700,   25000,   28000,     342,   33000,
#            332,    8800,   40000,   30000,    9300,   37000,     115,
#          31000,    6000,      76,     147,   34000,     120,    9400,
#          36000,   38000,   44000,   14000,   41000,    8300,    7800,
#           9900,   16000,    7100,     214,     186,      91,    6800,
#          57000,   39000,    6100,    6600,    8200,   42000,   11000,
#           7700,  183000,    8000,   46000,   45000,     161,    4600,
#            854,   43000,    8500,   51000,    3900,   86000,    1800,
#          50000,     181,   55000,   52000,    8900,   79000,   62000,
# ...

# %%
 df['link'].unique()
# Out:
# array(['https://ted.com/talks/ozawa_bineshi_albert_climate_action_needs_new_frontline_leadership',
#        'https://ted.com/talks/sydney_iaukea_the_dark_history_of_the_overthrow_of_hawaii',
#        'https://ted.com/talks/martin_reeves_how_play_can_spark_new_ideas_for_your_business',
#        ..., 'https://ted.com/talks/majora_carter_greening_the_ghetto',
#        'https://ted.com/talks/david_pogue_simplicity_sells',
#        'https://ted.com/talks/al_gore_averting_the_climate_crisis'],
#       dtype=object)

# %%
sns.countplot(df["views"])

# %% [markdown]
# #we check the views counts and count of views is near by 200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
top_10 = df['views'].value_counts()[:10]
top_10.plot(kind='bar',figsize=(10,8))
plt.title('Top 10 views')
# Out:
# Text(0.5, 1.0, 'Top 10 views')

# %% [markdown]
# # we check the top 10 views and the the top10 views range is between 1300000 to 1900000 .1300000 count views is around 250

# %%
top_10 = df['author'].value_counts()[:10]
top_10.plot(kind='bar',figsize=(10,8))
plt.title('Top 10 author')
# Out:
# Text(0.5, 1.0, 'Top 10 author')

# %% [markdown]
# # we check the count top 10 author and the Alex Gendler is the heigest author and his count 45

# %%
top_10 = df['likes'].value_counts()[:10]
top_10.plot(kind='bar',figsize=(10,8))
plt.title('Top 10 likes')
# Out:
# Text(0.5, 1.0, 'Top 10 likes')

# %% [markdown]
# # we check top 10 most likes value count and the heighest count is 39000 is around 85

# %%
top_10 = df['title'].value_counts()[:10]
top_10.plot(kind='bar',figsize=(10,8))
plt.title('Top 10 title book')
# Out:
# Text(0.5, 1.0, 'Top 10 title book')

# %% [markdown]
# # we check the top 10 title book

# %%
plt.figure(figsize=(15, 5))
df['author'].value_counts()[:10]
sns.countplot(data=df, x='author')
plt.xticks(rotation=75)
plt.title('top 10 heighest author ')
plt.xlabel('author')
plt.ylabel('views')
# Out:
# Text(0, 0.5, 'views')

# %%
#Checking the number of title in dataset
df.loc[:,'title'].value_counts().sum()
# Out:
# 5440

# %%
top_tedx = df.loc[0:9,['title','views']].sort_values(by='views', ascending=False, ignore_index=True)
top_tedx
# Out:
#                                                title   views
# 0     The origins of blackface and Black stereotypes  584000
# 1         You deserve the right to repair your stuff  455000
# 2  Why is China appointing judges to combat clima...  427000
# 3  The tragedy of air pollution — and an urgent d...  422000
# 4     How play can spark new ideas for your business  412000
# 5                     The myth of Narcissus and Echo  412000
# 6      Climate action needs new frontline leadership  404000
# 7        The dark history of the overthrow of Hawaii  214000
# 8  What nature can teach us about sustainable bus...   66000
# 9     Cement's carbon problem — and 2 ways to fix it    2400

# %% [markdown]
# #checking the  title vs views

# %%
#Checking the number of talks for every speaker
print(df.loc[:,'author'].value_counts())
# Out:
# Alex Gendler             45
# Iseult Gillespie         33
# Matt Walker              18
# Alex Rosenthal           15
# Elizabeth Cox            13
#                          ..
# Trevor Timm               1
# Sherry Turkle             1
# David Holt                1
# Chrystina Russell         1
# Christopher Robichaud     1
# Name: author, Length: 4443, dtype: int64

# %% [markdown]
# #Checking the number of talks for every speaker
